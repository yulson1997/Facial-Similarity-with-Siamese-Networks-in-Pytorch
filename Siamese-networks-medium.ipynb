# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "./data/faces/training/"
    testing_dir = "./data/faces/testing/"
    train_batch_size = 8
    train_number_epochs = 100

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# 0.08685027807950974
#
# Epoch number 22
#  Current loss 0.09006718546152115
#
# Epoch number 22
#  Current loss 0.24040073156356812
#
# Epoch number 22
#  Current loss 0.09175363183021545
#
# Epoch number 22
#  Current loss 0.31106841564178467
#
# Epoch number 22
#  Current loss 0.018994800746440887
#
# Epoch number 23
#  Current loss 0.07770708203315735
#
# Epoch number 23
#  Current loss 0.11951351165771484
#
# Epoch number 23
#  Current loss 0.013545392081141472
#
# Epoch number 23
#  Current loss 0.08283345401287079
#
# Epoch number 23
#  Current loss 0.06192852184176445
#
# Epoch number 24
#  Current loss 0.1864728033542633
#
# Epoch number 24
#  Current loss 0.1159648597240448
#
# Epoch number 24
#  Current loss 0.1226993128657341
#
# Epoch number 24
#  Current loss 0.1492307484149933
#
# Epoch number 24
#  Current loss 0.31432628631591797
#
# Epoch number 25
#  Current loss 0.12282694876194
#
# Epoch number 25
#  Current loss 0.4678100049495697
#
# Epoch number 25
#  Current loss 0.2933546304702759
#
# Epoch number 25
#  Current loss 0.1906108856201172
#
# Epoch number 25
#  Current loss 0.3045886158943176
#
# Epoch number 26
#  Current loss 0.050430960953235626
#
# Epoch number 26
#  Current loss 0.1127251461148262
#
# Epoch number 26
#  Current loss 0.23445738852024078
#
# Epoch number 26
#  Current loss 0.32025909423828125
#
# Epoch number 26
#  Current loss 0.5944152474403381
#
# Epoch number 27
#  Current loss 0.05793318897485733
#
# Epoch number 27
#  Current loss 0.03505353629589081
#
# Epoch number 27
#  Current loss 0.5064080953598022
#
# Epoch number 27
#  Current loss 0.40446919202804565
#
# Epoch number 27
#  Current loss 0.14359845221042633
#
# Epoch number 28
#  Current loss 0.21047230064868927
#
# Epoch number 28
#  Current loss 0.11894778162240982
#
# Epoch number 28
#  Current loss 0.23269599676132202
#
# Epoch number 28
#  Current loss 0.05809738487005234
#
# Epoch number 28
#  Current loss 0.049201443791389465
#
# Epoch number 29
#  Current loss 0.11043223738670349
#
# Epoch number 29
#  Current loss 0.12632080912590027
#
# Epoch number 29
#  Current loss 0.10604843497276306
#
# Epoch number 29
#  Current loss 0.059309400618076324
#
# Epoch number 29
#  Current loss 0.1448109745979309
#
# Epoch number 30
#  Current loss 0.1772649586200714
#
# Epoch number 30
#  Current loss 0.09007587283849716
#
# Epoch number 30
#  Current loss 0.10151159763336182
#
# Epoch number 30
#  Current loss 0.2768840789794922
#
# Epoch number 30
#  Current loss 0.09499001502990723
#
# Epoch number 31
#  Current loss 0.031572114676237106
#
# Epoch number 31
#  Current loss 0.10575547069311142
#
# Epoch number 31
#  Current loss 0.07313556224107742
#
# Epoch number 31
#  Current loss 0.03429298847913742
#
# Epoch number 31
#  Current loss 0.12050404399633408
#
# Epoch number 32
#  Current loss 0.09405113011598587
#
# Epoch number 32
#  Current loss 0.13315260410308838
#
# Epoch number 32
#  Current loss 0.14117340743541718
#
# Epoch number 32
#  Current loss 0.11536829173564911
#
# Epoch number 32
#  Current loss 0.10592087358236313
#
# Epoch number 33
#  Current loss 0.14761778712272644
#
# Epoch number 33
#  Current loss 0.07032954692840576
#
# Epoch number 33
#  Current loss 0.07449392229318619
#
# Epoch number 33
#  Current loss 0.06682605296373367
#
# Epoch number 33
#  Current loss 0.05758444964885712
#
# Epoch number 34
#  Current loss 0.03494107723236084
#
# Epoch number 34
#  Current loss 0.0753430426120758
#
# Epoch number 34
#  Current loss 0.13882948458194733
#
# Epoch number 34
#  Current loss 0.03317234665155411
#
# Epoch number 34
#  Current loss 0.0551195964217186
#
# Epoch number 35
#  Current loss 0.12728606164455414
#
# Epoch number 35
#  Current loss 0.04003150761127472
#
# Epoch number 35
#  Current loss 0.03885854780673981
#
# Epoch number 35
#  Current loss 0.04923030734062195
#
# Epoch number 35
#  Current loss 0.06762430816888809
#
# Epoch number 36
#  Current loss 0.08788920193910599
#
# Epoch number 36
#  Current loss 0.00619026692584157
#
# Epoch number 36
#  Current loss 0.012707522138953209
#
# Epoch number 36
#  Current loss 0.032829657196998596
#
# Epoch number 36
#  Current loss 0.07651901245117188
#
# Epoch number 37
#  Current loss 0.027877215296030045
#
# Epoch number 37
#  Current loss 0.13643963634967804
#
# Epoch number 37
#  Current loss 0.08341403305530548
#
# Epoch number 37
#  Current loss 0.07992438971996307
#
# Epoch number 37
#  Current loss 0.07469788938760757
#
# Epoch number 38
#  Current loss 0.019645584747195244
#
# Epoch number 38
#  Current loss 0.04215099290013313
#
# Epoch number 38
#  Current loss 0.15682506561279297
#
# Epoch number 38
#  Current loss 0.1051081120967865
#
# Epoch number 38
#  Current loss 0.043083660304546356
#
# Epoch number 39
#  Current loss 0.10781638324260712
#
# Epoch number 39
#  Current loss 0.13395671546459198
#
# Epoch number 39
#  Current loss 0.1344604194164276
#
# Epoch number 39
#  Current loss 0.0706244558095932
#
# Epoch number 39
#  Current loss 0.034173641353845596
#
# Epoch number 40
#  Current loss 0.029917895793914795
#
# Epoch number 40
#  Current loss 0.07880033552646637
#
# Epoch number 40
#  Current loss 0.011396014131605625
#
# Epoch number 40
#  Current loss 0.0313180610537529
#
# Epoch number 40
#  Current loss 0.0512455515563488
#
# Epoch number 41
#  Current loss 0.02955535054206848
#
# Epoch number 41
#  Current loss 0.07423405349254608
#
# Epoch number 41
#  Current loss 0.0
#
# Epoch number 41
#  Current loss 0.31458160281181335
#
# Epoch number 41
#  Current loss 0.045527394860982895
#
# Epoch number 42
#  Current loss 0.03612002730369568
#
# Epoch number 42
#  Current loss 0.1144566535949707
#
# Epoch number 42
#  Current loss 0.24056972563266754
#
# Epoch number 42
#  Current loss 0.04758314788341522
#
# Epoch number 42
#  Current loss 0.11233360320329666
#
# Epoch number 43
#  Current loss 0.29134660959243774
#
# Epoch number 43
#  Current loss 0.008987383916974068
#
# Epoch number 43
#  Current loss 0.008555137552320957
#
# Epoch number 43
#  Current loss 0.03524155169725418
#
# Epoch number 43
#  Current loss 0.11175192892551422
#
# Epoch number 44
#  Current loss 0.09089545905590057
#
# Epoch number 44
#  Current loss 0.058256134390830994
#
# Epoch number 44
#  Current loss 0.03954005986452103
#
# Epoch number 44
#  Current loss 0.01850292645394802
#
# Epoch number 44
#  Current loss 0.14892713725566864
#
# Epoch number 45
#  Current loss 0.045680224895477295
#
# Epoch number 45
#  Current loss 0.02207917720079422
#
# Epoch number 45
#  Current loss 0.040185827761888504
#
# Epoch number 45
#  Current loss 0.037498340010643005
#
# Epoch number 45
#  Current loss 0.2005387842655182
#
# Epoch number 46
#  Current loss 0.08170256018638611
#
# Epoch number 46
#  Current loss 0.0071608684957027435
#
# Epoch number 46
#  Current loss 0.08423357456922531
#
# Epoch number 46
#  Current loss 0.011171326041221619
#
# Epoch number 46
#  Current loss 0.033704690635204315
#
# Epoch number 47
#  Current loss 0.0901859924197197
#
# Epoch number 47
#  Current loss 0.06362180411815643
#
# Epoch number 47
#  Current loss 0.03274684399366379
#
# Epoch number 47
#  Current loss 0.15135034918785095
#
# Epoch number 47
#  Current loss 0.026810813695192337
#
# Epoch number 48
#  Current loss 0.01690184511244297
#
# Epoch number 48
#  Current loss 0.07751762866973877
#
# Epoch number 48
#  Current loss 0.09963881969451904
#
# Epoch number 48
#  Current loss 0.05793771892786026
#
# Epoch number 48
#  Current loss 0.13175129890441895
#
# Epoch number 49
#  Current loss 0.029673879966139793
#
# Epoch number 49
#  Current loss 0.014021571725606918
#
# Epoch number 49
#  Current loss 0.08020634949207306
#
# Epoch number 49
#  Current loss 0.0077120354399085045
#
# Epoch number 49
#  Current loss 0.010963696986436844
#
# Epoch number 50
#  Current loss 0.07400108873844147
#
# Epoch number 50
#  Current loss 0.03483765944838524
#
# Epoch number 50
#  Current loss 0.029941730201244354
#
# Epoch number 50
#  Current loss 0.09316554665565491
#
# Epoch number 50
#  Current loss 0.21693845093250275
#
# Epoch number 51
#  Current loss 0.10303454101085663
#
# Epoch number 51
#  Current loss 0.015956221148371696
#
# Epoch number 51
#  Current loss 0.0419449545443058
#
# Epoch number 51
#  Current loss 0.011630023829638958
#
# Epoch number 51
#  Current loss 0.017901217564940453
#
# Epoch number 52
#  Current loss 0.009052926674485207
#
# Epoch number 52
#  Current loss 0.027473121881484985
#
# Epoch number 52
#  Current loss 0.032872434705495834
#
# Epoch number 52
#  Current loss 0.09926806390285492
#
# Epoch number 52
#  Current loss 0.11310754716396332
#
# Epoch number 53
#  Current loss 0.02910616248846054
#
# Epoch number 53
#  Current loss 0.043959841132164
#
# Epoch number 53
#  Current loss 0.04177584499120712
#
# Epoch number 53
#  Current loss 0.07561387121677399
#
# Epoch number 53
#  Current loss 0.0022407779470086098
#
# Epoch number 54
#  Current loss 0.1692695915699005
#
# Epoch number 54
#  Current loss 0.016851145774126053
#
# Epoch number 54
#  Current loss 0.07700175046920776
#
# Epoch number 54
#  Current loss 0.10934289544820786
#
# Epoch number 54
#  Current loss 0.007847597822546959
#
# Epoch number 55
#  Current loss 0.17144373059272766
#
# Epoch number 55
#  Current loss 0.13462233543395996
#
# Epoch number 55
#  Current loss 0.18314793705940247
#
# Epoch number 55
#  Current loss 0.03292001783847809
#
# Epoch number 55
#  Current loss 0.022132454439997673
#
# Epoch number 56
#  Current loss 0.06422203779220581
#
# Epoch number 56
#  Current loss 0.03211802989244461
#
# Epoch number 56
#  Current loss 0.05280299484729767
#
# Epoch number 56
#  Current loss 0.13506336510181427
#
# Epoch number 56
#  Current loss 0.04915454238653183
#
# Epoch number 57
#  Current loss 0.07971078902482986
#
# Epoch number 57
#  Current loss 0.044497616589069366
#
# Epoch number 57
#  Current loss 0.018514428287744522
#
# Epoch number 57
#  Current loss 0.037251561880111694
#
# Epoch number 57
#  Current loss 0.018999963998794556
#
# Epoch number 58
#  Current loss 0.14162155985832214
#
# Epoch number 58
#  Current loss 0.08308053016662598
#
# Epoch number 58
#  Current loss 0.11947024613618851
#
# Epoch number 58
#  Current loss 0.06702782958745956
#
# Epoch number 58
#  Current loss 0.1151176244020462
#
# Epoch number 59
#  Current loss 0.03118837997317314
#
# Epoch number 59
#  Current loss 0.04532364755868912
#
# Epoch number 59
#  Current loss 0.05941572040319443
#
# Epoch number 59
#  Current loss 0.009767181240022182
#
# Epoch number 59
#  Current loss 0.04834956303238869
#
# Epoch number 60
#  Current loss 0.021593108773231506
#
# Epoch number 60
#  Current loss 0.16505633294582367
#
# Epoch number 60
#  Current loss 0.026036055758595467
#
# Epoch number 60
#  Current loss 0.03812706097960472
#
# Epoch number 60
#  Current loss 0.03354616090655327
#
# Epoch number 61
#  Current loss 0.022468000650405884
#
# Epoch number 61
#  Current loss 0.014430630020797253
#
# Epoch number 61
#  Current loss 0.059648264199495316
#
# Epoch number 61
#  Current loss 0.030691346153616905
#
# Epoch number 61
#  Current loss 0.03035128302872181
#
# Epoch number 62
#  Current loss 0.04272119700908661
#
# Epoch number 62
#  Current loss 0.015833616256713867
#
# Epoch number 62
#  Current loss 0.04521734267473221
#
# Epoch number 62
#  Current loss 0.042186181992292404
#
# Epoch number 62
#  Current loss 0.07861397415399551
#
# Epoch number 63
#  Current loss 0.027747204527258873
#
# Epoch number 63
#  Current loss 0.029157008975744247
#
# Epoch number 63
#  Current loss 0.020178772509098053
#
# Epoch number 63
#  Current loss 0.11046967655420303
#
# Epoch number 63
#  Current loss 0.0062734829261898994
#
# Epoch number 64
#  Current loss 0.021543849259614944
#
# Epoch number 64
#  Current loss 0.019451487809419632
#
# Epoch number 64
#  Current loss 0.015183541923761368
#
# Epoch number 64
#  Current loss 0.09021110832691193
#
# Epoch number 64
#  Current loss 0.018547233194112778
#
# Epoch number 65
#  Current loss 0.05985397845506668
#
# Epoch number 65
#  Current loss 0.032978612929582596
#
# Epoch number 65
#  Current loss 0.08562629669904709
#
# Epoch number 65
#  Current loss 0.017193127423524857
#
# Epoch number 65
#  Current loss 0.01876888982951641
#
# Epoch number 66
#  Current loss 0.012237061746418476
#
# Epoch number 66
#  Current loss 0.021331261843442917
#
# Epoch number 66
#  Current loss 0.01888793148100376
#
# Epoch number 66
#  Current loss 0.032113030552864075
#
# Epoch number 66
#  Current loss 0.04198654741048813
#
# Epoch number 67
#  Current loss 0.0577302947640419
#
# Epoch number 67
#  Current loss 0.01530039869248867
#
# Epoch number 67
#  Current loss 0.031802818179130554
#
# Epoch number 67
#  Current loss 0.03383138030767441
#
# Epoch number 67
#  Current loss 0.022530708461999893
#
# Epoch number 68
#  Current loss 0.030499249696731567
#
# Epoch number 68
#  Current loss 0.00238391337916255
#
# Epoch number 68
#  Current loss 0.007258196361362934
#
# Epoch number 68
#  Current loss 0.08628994226455688
#
# Epoch number 68
#  Current loss 0.02021484449505806
#
# Epoch number 69
#  Current loss 0.04537326842546463
#
# Epoch number 69
#  Current loss 0.018685810267925262
#
# Epoch number 69
#  Current loss 0.024702152237296104
#
# Epoch number 69
#  Current loss 0.0034584850072860718
#
# Epoch number 69
#  Current loss 0.03479630872607231
#
# Epoch number 70
#  Current loss 0.01470191776752472
#
# Epoch number 70
#  Current loss 0.024182317778468132
#
# Epoch number 70
#  Current loss 0.03619220480322838
#
# Epoch number 70
#  Current loss 0.04291975125670433
#
# Epoch number 70
#  Current loss 0.030339859426021576
#
# Epoch number 71
#  Current loss 0.00624180817976594
#
# Epoch number 71
#  Current loss 0.03040751814842224
#
# Epoch number 71
#  Current loss 0.04236340895295143
#
# Epoch number 71
#  Current loss 0.057689931243658066
#
# Epoch number 71
#  Current loss 0.05908790975809097
#
# Epoch number 72
#  Current loss 0.026451371610164642
#
# Epoch number 72
#  Current loss 0.03177966549992561
#
# Epoch number 72
#  Current loss 0.029335781931877136
#
# Epoch number 72
#  Current loss 0.018597330898046494
#
# Epoch number 72
#  Current loss 0.00249633751809597
#
# Epoch number 73
#  Current loss 0.0360601581633091
#
# Epoch number 73
#  Current loss 0.0
#
# Epoch number 73
#  Current loss 0.021205229684710503
#
# Epoch number 73
#  Current loss 0.023886490613222122
#
# Epoch number 73
#  Current loss 0.016777753829956055
#
# Epoch number 74
#  Current loss 0.010280587710440159
#
# Epoch number 74
#  Current loss 0.031142793595790863
#
# Epoch number 74
#  Current loss 0.02885282412171364
#
# Epoch number 74
#  Current loss 0.023887699469923973
#
# Epoch number 74
#  Current loss 0.08063144981861115
#
# Epoch number 75
#  Current loss 0.0516199953854084
#
# Epoch number 75
#  Current loss 0.009087365120649338
#
# Epoch number 75
#  Current loss 0.021452846005558968
#
# Epoch number 75
#  Current loss 0.008736266754567623
#
# Epoch number 75
#  Current loss 0.015567636117339134
#
# Epoch number 76
#  Current loss 0.014214145950973034
#
# Epoch number 76
#  Current loss 0.025551363825798035
#
# Epoch number 76
#  Current loss 0.03540503978729248
#
# Epoch number 76
#  Current loss 0.08981649577617645
#
# Epoch number 76
#  Current loss 0.016533078625798225
#
# Epoch number 77
#  Current loss 0.005145323928445578
#
# Epoch number 77
#  Current loss 0.026158157736063004
#
# Epoch number 77
#  Current loss 0.0025687688030302525
#
# Epoch number 77
#  Current loss 0.008076709695160389
#
# Epoch number 77
#  Current loss 0.04099586606025696
#
# Epoch number 78
#  Current loss 0.03673544526100159
#
# Epoch number 78
#  Current loss 0.0488407164812088
#
# Epoch number 78
#  Current loss 0.00814818125218153
#
# Epoch number 78
#  Current loss 0.04247136414051056
#
# Epoch number 78
#  Current loss 0.058822739869356155
#
# Epoch number 79
#  Current loss 0.012258274480700493
#
# Epoch number 79
#  Current loss 0.030214674770832062
#
# Epoch number 79
#  Current loss 0.058572400361299515
#
# Epoch number 79
#  Current loss 0.008717033080756664
#
# Epoch number 79
#  Current loss 0.01008879765868187
#
# Epoch number 80
#  Current loss 0.08873464167118073
#
# Epoch number 80
#  Current loss 0.023402171209454536
#
# Epoch number 80
#  Current loss 0.03677205368876457
#
# Epoch number 80
#  Current loss 0.0600447803735733
#
# Epoch number 80
#  Current loss 0.03525817394256592
#
# Epoch number 81
#  Current loss 0.005196535959839821
#
# Epoch number 81
#  Current loss 0.033262040466070175
#
# Epoch number 81
#  Current loss 0.03148995339870453
#
# Epoch number 81
#  Current loss 0.03452834486961365
#
# Epoch number 81
#  Current loss 0.02039904147386551
#
# Epoch number 82
#  Current loss 0.0027073624078184366
#
# Epoch number 82
#  Current loss 0.015632646158337593
#
# Epoch number 82
#  Current loss 0.02923409640789032
#
# Epoch number 82
#  Current loss 0.07077068090438843
#
# Epoch number 82
#  Current loss 0.015943588688969612
#
# Epoch number 83
#  Current loss 0.02858423814177513
#
# Epoch number 83
#  Current loss 0.028317373245954514
#
# Epoch number 83
#  Current loss 0.01969197764992714
#
# Epoch number 83
#  Current loss 0.01685371994972229
#
# Epoch number 83
#  Current loss 0.024673841893672943
#
# Epoch number 84
#  Current loss 0.08667115867137909
#
# Epoch number 84
#  Current loss 0.028019560500979424
#
# Epoch number 84
#  Current loss 0.014740627259016037
#
# Epoch number 84
#  Current loss 0.02957916259765625
#
# Epoch number 84
#  Current loss 0.03982901573181152
#
# Epoch number 85
#  Current loss 0.0598309226334095
#
# Epoch number 85
#  Current loss 0.02728874236345291
#
# Epoch number 85
#  Current loss 0.036802951246500015
#
# Epoch number 85
#  Current loss 0.01787177287042141
#
# Epoch number 85
#  Current loss 0.018471427261829376
#
# Epoch number 86
#  Current loss 0.02712620422244072
#
# Epoch number 86
#  Current loss 0.0064148074015975
#
# Epoch number 86
#  Current loss 0.04452859237790108
#
# Epoch number 86
#  Current loss 0.05428771674633026
#
# Epoch number 86
#  Current loss 0.15710528194904327
#
# Epoch number 87
#  Current loss 0.002590238582342863
#
# Epoch number 87
#  Current loss 0.021210094913840294
#
# Epoch number 87
#  Current loss 0.02260288968682289
#
# Epoch number 87
#  Current loss 0.027127902954816818
#
# Epoch number 87
#  Current loss 0.08360861986875534
#
# Epoch number 88
#  Current loss 0.006770001258701086
#
# Epoch number 88
#  Current loss 0.039937056601047516
#
# Epoch number 88
#  Current loss 0.021524958312511444
#
# Epoch number 88
#  Current loss 0.03632122650742531
#
# Epoch number 88
#  Current loss 0.01788061484694481
#
# Epoch number 89
#  Current loss 0.034518562257289886
#
# Epoch number 89
#  Current loss 0.031224437057971954
#
# Epoch number 89
#  Current loss 0.031451206654310226
#
# Epoch number 89
#  Current loss 0.005656273569911718
#
# Epoch number 89
#  Current loss 0.015373933129012585
#
# Epoch number 90
#  Current loss 0.024165639653801918
#
# Epoch number 90
#  Current loss 0.015337217599153519
#
# Epoch number 90
#  Current loss 0.02024361491203308
#
# Epoch number 90
#  Current loss 0.02700108289718628
#
# Epoch number 90
#  Current loss 0.009655829519033432
#
# Epoch number 91
#  Current loss 0.006919989828020334
#
# Epoch number 91
#  Current loss 0.019364601001143456
#
# Epoch number 91
#  Current loss 0.06591145694255829
#
# Epoch number 91
#  Current loss 0.026797963306307793
#
# Epoch number 91
#  Current loss 0.006433001719415188
#
# Epoch number 92
#  Current loss 0.0633714571595192
#
# Epoch number 92
#  Current loss 0.032274745404720306
#
# Epoch number 92
#  Current loss 0.07797014713287354
#
# Epoch number 92
#  Current loss 0.02240345999598503
#
# Epoch number 92
#  Current loss 0.008065653033554554
#
# Epoch number 93
#  Current loss 0.008282564580440521
#
# Epoch number 93
#  Current loss 0.03117542341351509
#
# Epoch number 93
#  Current loss 0.027115125209093094
#
# Epoch number 93
#  Current loss 0.01898135058581829
#
# Epoch number 93
#  Current loss 0.056312400847673416
#
# Epoch number 94
#  Current loss 0.012711675837635994
#
# Epoch number 94
#  Current loss 0.02414853870868683
#
# Epoch number 94
#  Current loss 0.07817324995994568
#
# Epoch number 94
#  Current loss 0.051876965910196304
#
# Epoch number 94
#  Current loss 0.014269565232098103
#
# Epoch number 95
#  Current loss 0.01427370123565197
#
# Epoch number 95
#  Current loss 0.11566773056983948
#
# Epoch number 95
#  Current loss 0.011358212679624557
#
# Epoch number 95
#  Current loss 0.026347924023866653
#
# Epoch number 95
#  Current loss 0.02651039883494377
#
# Epoch number 96
#  Current loss 0.045069627463817596
#
# Epoch number 96
#  Current loss 0.007461716886609793
#
# Epoch number 96
#  Current loss 0.026872720569372177
#
# Epoch number 96
#  Current loss 0.039740271866321564
#
# Epoch number 96
#  Current loss 0.0296971146017313
#
# Epoch number 97
#  Current loss 0.042395565658807755
#
# Epoch number 97
#  Current loss 0.014740752056241035
#
# Epoch number 97
#  Current loss 0.008321142755448818
#
# Epoch number 97
#  Current loss 0.04205920174717903
#
# Epoch number 97
#  Current loss 0.041918735951185226
#
# Epoch number 98
#  Current loss 0.010515457019209862
#
# Epoch number 98
#  Current loss 0.023162834346294403
#
# Epoch number 98
#  Current loss 0.010807661339640617
#
# Epoch number 98
#  Current loss 0.017697589471936226
#
# Epoch number 98
#  Current loss 0.036250125616788864
#
# Epoch number 99
#  Current loss 0.05579914525151253
#
# Epoch number 99
#  Current loss 0.011305947788059711
#
# Epoch number 99
#  Current loss 0.06263485550880432
#
# Epoch number 99
#  Current loss 0.04965329170227051
#
# Epoch number 99
#  Current loss 0.02518439292907715

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
