# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "./data/faces/training/"
    testing_dir = "./data/faces/testing/"
    train_batch_size = 8
    train_number_epochs = 100

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# 9
#
# Epoch number 21
#  Current loss 0.08721280097961426
#
# Epoch number 22
#  Current loss 0.039351046085357666
#
# Epoch number 22
#  Current loss 0.07160217314958572
#
# Epoch number 22
#  Current loss 0.017983095720410347
#
# Epoch number 22
#  Current loss 0.04861806705594063
#
# Epoch number 22
#  Current loss 0.08034604787826538
#
# Epoch number 23
#  Current loss 0.05717892199754715
#
# Epoch number 23
#  Current loss 0.019531436264514923
#
# Epoch number 23
#  Current loss 0.15146997570991516
#
# Epoch number 23
#  Current loss 0.06348641216754913
#
# Epoch number 23
#  Current loss 0.06937026977539062
#
# Epoch number 24
#  Current loss 0.06783230602741241
#
# Epoch number 24
#  Current loss 0.08459635823965073
#
# Epoch number 24
#  Current loss 0.06840168684720993
#
# Epoch number 24
#  Current loss 0.10179369896650314
#
# Epoch number 24
#  Current loss 0.39279890060424805
#
# Epoch number 25
#  Current loss 0.05891025811433792
#
# Epoch number 25
#  Current loss 0.03338067978620529
#
# Epoch number 25
#  Current loss 0.08447103202342987
#
# Epoch number 25
#  Current loss 0.08668339252471924
#
# Epoch number 25
#  Current loss 0.10226587951183319
#
# Epoch number 26
#  Current loss 0.058551203459501266
#
# Epoch number 26
#  Current loss 0.03388728201389313
#
# Epoch number 26
#  Current loss 0.02604612335562706
#
# Epoch number 26
#  Current loss 0.09234160929918289
#
# Epoch number 26
#  Current loss 0.04474751651287079
#
# Epoch number 27
#  Current loss 0.11572542041540146
#
# Epoch number 27
#  Current loss 0.22147050499916077
#
# Epoch number 27
#  Current loss 0.31660595536231995
#
# Epoch number 27
#  Current loss 0.14540168642997742
#
# Epoch number 27
#  Current loss 0.028675898909568787
#
# Epoch number 28
#  Current loss 0.04717911779880524
#
# Epoch number 28
#  Current loss 0.18705502152442932
#
# Epoch number 28
#  Current loss 0.23839865624904633
#
# Epoch number 28
#  Current loss 0.08493077754974365
#
# Epoch number 28
#  Current loss 0.282438725233078
#
# Epoch number 29
#  Current loss 0.21189960837364197
#
# Epoch number 29
#  Current loss 0.12739084661006927
#
# Epoch number 29
#  Current loss 0.09301616251468658
#
# Epoch number 29
#  Current loss 0.06176982820034027
#
# Epoch number 29
#  Current loss 0.0641712173819542
#
# Epoch number 30
#  Current loss 0.03488187491893768
#
# Epoch number 30
#  Current loss 0.07999911904335022
#
# Epoch number 30
#  Current loss 0.07388655841350555
#
# Epoch number 30
#  Current loss 0.10174122452735901
#
# Epoch number 30
#  Current loss 0.032303325831890106
#
# Epoch number 31
#  Current loss 0.09452502429485321
#
# Epoch number 31
#  Current loss 0.11682885140180588
#
# Epoch number 31
#  Current loss 0.2359866499900818
#
# Epoch number 31
#  Current loss 0.037419192492961884
#
# Epoch number 31
#  Current loss 0.03765004128217697
#
# Epoch number 32
#  Current loss 0.09043669700622559
#
# Epoch number 32
#  Current loss 0.050516292452812195
#
# Epoch number 32
#  Current loss 0.1310889571905136
#
# Epoch number 32
#  Current loss 0.11687380820512772
#
# Epoch number 32
#  Current loss 0.05070767551660538
#
# Epoch number 33
#  Current loss 0.02201002836227417
#
# Epoch number 33
#  Current loss 0.038834892213344574
#
# Epoch number 33
#  Current loss 0.02368505671620369
#
# Epoch number 33
#  Current loss 0.03678279370069504
#
# Epoch number 33
#  Current loss 0.016946766525506973
#
# Epoch number 34
#  Current loss 0.042894311249256134
#
# Epoch number 34
#  Current loss 0.3839413821697235
#
# Epoch number 34
#  Current loss 0.03493513911962509
#
# Epoch number 34
#  Current loss 0.12217001616954803
#
# Epoch number 34
#  Current loss 0.1100761890411377
#
# Epoch number 35
#  Current loss 0.019694816321134567
#
# Epoch number 35
#  Current loss 0.0312606580555439
#
# Epoch number 35
#  Current loss 0.09817072749137878
#
# Epoch number 35
#  Current loss 0.049474652856588364
#
# Epoch number 35
#  Current loss 0.014447007328271866
#
# Epoch number 36
#  Current loss 0.05805221572518349
#
# Epoch number 36
#  Current loss 0.07629270106554031
#
# Epoch number 36
#  Current loss 0.06447827816009521
#
# Epoch number 36
#  Current loss 0.038629982620477676
#
# Epoch number 36
#  Current loss 0.08369617164134979
#
# Epoch number 37
#  Current loss 0.017761196941137314
#
# Epoch number 37
#  Current loss 0.025592811405658722
#
# Epoch number 37
#  Current loss 0.03800959885120392
#
# Epoch number 37
#  Current loss 0.04738687723875046
#
# Epoch number 37
#  Current loss 0.07650585472583771
#
# Epoch number 38
#  Current loss 0.11790809035301208
#
# Epoch number 38
#  Current loss 0.02134767547249794
#
# Epoch number 38
#  Current loss 0.1145135909318924
#
# Epoch number 38
#  Current loss 0.1538102775812149
#
# Epoch number 38
#  Current loss 0.017070544883608818
#
# Epoch number 39
#  Current loss 0.025900013744831085
#
# Epoch number 39
#  Current loss 0.1119316965341568
#
# Epoch number 39
#  Current loss 0.016835052520036697
#
# Epoch number 39
#  Current loss 0.015063975937664509
#
# Epoch number 39
#  Current loss 0.044593483209609985
#
# Epoch number 40
#  Current loss 0.016641493886709213
#
# Epoch number 40
#  Current loss 0.01198061928153038
#
# Epoch number 40
#  Current loss 0.081132672727108
#
# Epoch number 40
#  Current loss 0.023330148309469223
#
# Epoch number 40
#  Current loss 0.038279011845588684
#
# Epoch number 41
#  Current loss 0.042776644229888916
#
# Epoch number 41
#  Current loss 0.013475105166435242
#
# Epoch number 41
#  Current loss 0.1380283534526825
#
# Epoch number 41
#  Current loss 0.09951988607645035
#
# Epoch number 41
#  Current loss 0.07617267966270447
#
# Epoch number 42
#  Current loss 0.03363652527332306
#
# Epoch number 42
#  Current loss 0.15057258307933807
#
# Epoch number 42
#  Current loss 0.002841125475242734
#
# Epoch number 42
#  Current loss 0.011745510622859001
#
# Epoch number 42
#  Current loss 0.10016986727714539
#
# Epoch number 43
#  Current loss 0.021567583084106445
#
# Epoch number 43
#  Current loss 0.09465745091438293
#
# Epoch number 43
#  Current loss 0.10290314257144928
#
# Epoch number 43
#  Current loss 0.09576380252838135
#
# Epoch number 43
#  Current loss 0.1305396556854248
#
# Epoch number 44
#  Current loss 0.20050883293151855
#
# Epoch number 44
#  Current loss 0.1419743299484253
#
# Epoch number 44
#  Current loss 0.07012736797332764
#
# Epoch number 44
#  Current loss 0.09485720098018646
#
# Epoch number 44
#  Current loss 0.05685921758413315
#
# Epoch number 45
#  Current loss 0.09974532574415207
#
# Epoch number 45
#  Current loss 0.06301364302635193
#
# Epoch number 45
#  Current loss 0.049746617674827576
#
# Epoch number 45
#  Current loss 0.03878828138113022
#
# Epoch number 45
#  Current loss 0.06562966108322144
#
# Epoch number 46
#  Current loss 0.017643004655838013
#
# Epoch number 46
#  Current loss 0.02841779589653015
#
# Epoch number 46
#  Current loss 0.05965258181095123
#
# Epoch number 46
#  Current loss 0.07228123396635056
#
# Epoch number 46
#  Current loss 0.011301621794700623
#
# Epoch number 47
#  Current loss 0.09171265363693237
#
# Epoch number 47
#  Current loss 0.017604166641831398
#
# Epoch number 47
#  Current loss 0.0370166189968586
#
# Epoch number 47
#  Current loss 0.034637704491615295
#
# Epoch number 47
#  Current loss 0.18592208623886108
#
# Epoch number 48
#  Current loss 0.1324150711297989
#
# Epoch number 48
#  Current loss 0.0946820080280304
#
# Epoch number 48
#  Current loss 0.018983522430062294
#
# Epoch number 48
#  Current loss 0.005656154826283455
#
# Epoch number 48
#  Current loss 0.015376059338450432
#
# Epoch number 49
#  Current loss 0.04785557836294174
#
# Epoch number 49
#  Current loss 0.06969225406646729
#
# Epoch number 49
#  Current loss 0.019458958879113197
#
# Epoch number 49
#  Current loss 0.03358299285173416
#
# Epoch number 49
#  Current loss 0.20578280091285706
#
# Epoch number 50
#  Current loss 0.0733279138803482
#
# Epoch number 50
#  Current loss 0.0289066843688488
#
# Epoch number 50
#  Current loss 0.022465480491518974
#
# Epoch number 50
#  Current loss 0.10404877364635468
#
# Epoch number 50
#  Current loss 0.014780675992369652
#
# Epoch number 51
#  Current loss 0.025370081886649132
#
# Epoch number 51
#  Current loss 0.05289367213845253
#
# Epoch number 51
#  Current loss 0.049747347831726074
#
# Epoch number 51
#  Current loss 0.016955144703388214
#
# Epoch number 51
#  Current loss 0.06834849715232849
#
# Epoch number 52
#  Current loss 0.030382946133613586
#
# Epoch number 52
#  Current loss 0.017127038910984993
#
# Epoch number 52
#  Current loss 0.1789429485797882
#
# Epoch number 52
#  Current loss 0.017287472262978554
#
# Epoch number 52
#  Current loss 0.08155010640621185
#
# Epoch number 53
#  Current loss 0.07846476137638092
#
# Epoch number 53
#  Current loss 0.07027940452098846
#
# Epoch number 53
#  Current loss 0.070347361266613
#
# Epoch number 53
#  Current loss 0.09642238169908524
#
# Epoch number 53
#  Current loss 0.02366877906024456
#
# Epoch number 54
#  Current loss 0.0181109718978405
#
# Epoch number 54
#  Current loss 0.039910122752189636
#
# Epoch number 54
#  Current loss 0.031041964888572693
#
# Epoch number 54
#  Current loss 0.26768195629119873
#
# Epoch number 54
#  Current loss 0.01620429754257202
#
# Epoch number 55
#  Current loss 0.04692979156970978
#
# Epoch number 55
#  Current loss 0.07924798130989075
#
# Epoch number 55
#  Current loss 0.04392983764410019
#
# Epoch number 55
#  Current loss 0.049764350056648254
#
# Epoch number 55
#  Current loss 0.015066759660840034
#
# Epoch number 56
#  Current loss 0.06345347315073013
#
# Epoch number 56
#  Current loss 0.053131215274333954
#
# Epoch number 56
#  Current loss 0.01756908930838108
#
# Epoch number 56
#  Current loss 0.06460420787334442
#
# Epoch number 56
#  Current loss 0.029643600806593895
#
# Epoch number 57
#  Current loss 0.01990368403494358
#
# Epoch number 57
#  Current loss 0.06703469157218933
#
# Epoch number 57
#  Current loss 0.07394476234912872
#
# Epoch number 57
#  Current loss 0.03302672877907753
#
# Epoch number 57
#  Current loss 0.0263260118663311
#
# Epoch number 58
#  Current loss 0.035106610506772995
#
# Epoch number 58
#  Current loss 0.010256876237690449
#
# Epoch number 58
#  Current loss 0.006274126935750246
#
# Epoch number 58
#  Current loss 0.04250229522585869
#
# Epoch number 58
#  Current loss 0.08836318552494049
#
# Epoch number 59
#  Current loss 0.10256069898605347
#
# Epoch number 59
#  Current loss 0.024436036124825478
#
# Epoch number 59
#  Current loss 0.02941683866083622
#
# Epoch number 59
#  Current loss 0.0067027872428298
#
# Epoch number 59
#  Current loss 0.05379211902618408
#
# Epoch number 60
#  Current loss 0.041021887212991714
#
# Epoch number 60
#  Current loss 0.06556139886379242
#
# Epoch number 60
#  Current loss 0.005492802243679762
#
# Epoch number 60
#  Current loss 0.026385022327303886
#
# Epoch number 60
#  Current loss 0.06765835732221603
#
# Epoch number 61
#  Current loss 0.10968315601348877
#
# Epoch number 61
#  Current loss 0.26962754130363464
#
# Epoch number 61
#  Current loss 0.110114187002182
#
# Epoch number 61
#  Current loss 0.07458053529262543
#
# Epoch number 61
#  Current loss 0.01574048213660717
#
# Epoch number 62
#  Current loss 0.07959568500518799
#
# Epoch number 62
#  Current loss 0.06923189759254456
#
# Epoch number 62
#  Current loss 0.04730977490544319
#
# Epoch number 62
#  Current loss 0.07963018119335175
#
# Epoch number 62
#  Current loss 0.17468926310539246
#
# Epoch number 63
#  Current loss 0.021223222836852074
#
# Epoch number 63
#  Current loss 0.3007165491580963
#
# Epoch number 63
#  Current loss 0.065048947930336
#
# Epoch number 63
#  Current loss 0.02370324730873108
#
# Epoch number 63
#  Current loss 0.07560328394174576
#
# Epoch number 64
#  Current loss 0.10629445314407349
#
# Epoch number 64
#  Current loss 0.04409511387348175
#
# Epoch number 64
#  Current loss 0.04667779058218002
#
# Epoch number 64
#  Current loss 0.019225629046559334
#
# Epoch number 64
#  Current loss 0.09593778103590012
#
# Epoch number 65
#  Current loss 0.11314002424478531
#
# Epoch number 65
#  Current loss 0.043000273406505585
#
# Epoch number 65
#  Current loss 0.006247400306165218
#
# Epoch number 65
#  Current loss 0.027384188026189804
#
# Epoch number 65
#  Current loss 0.010972259566187859
#
# Epoch number 66
#  Current loss 0.03231055662035942
#
# Epoch number 66
#  Current loss 0.03506394103169441
#
# Epoch number 66
#  Current loss 0.0395631343126297
#
# Epoch number 66
#  Current loss 0.0251716747879982
#
# Epoch number 66
#  Current loss 0.14288529753684998
#
# Epoch number 67
#  Current loss 0.07192676514387131
#
# Epoch number 67
#  Current loss 0.04440269619226456
#
# Epoch number 67
#  Current loss 0.03135848045349121
#
# Epoch number 67
#  Current loss 0.04008559137582779
#
# Epoch number 67
#  Current loss 0.10606047511100769
#
# Epoch number 68
#  Current loss 0.22315648198127747
#
# Epoch number 68
#  Current loss 0.092288538813591
#
# Epoch number 68
#  Current loss 0.1251285821199417
#
# Epoch number 68
#  Current loss 0.3627241849899292
#
# Epoch number 68
#  Current loss 0.026665376499295235
#
# Epoch number 69
#  Current loss 0.03353311866521835
#
# Epoch number 69
#  Current loss 0.019965022802352905
#
# Epoch number 69
#  Current loss 0.4360806941986084
#
# Epoch number 69
#  Current loss 0.15751737356185913
#
# Epoch number 69
#  Current loss 0.05266455188393593
#
# Epoch number 70
#  Current loss 0.2718978822231293
#
# Epoch number 70
#  Current loss 0.12951788306236267
#
# Epoch number 70
#  Current loss 0.21316641569137573
#
# Epoch number 70
#  Current loss 0.21070142090320587
#
# Epoch number 70
#  Current loss 0.22355468571186066
#
# Epoch number 71
#  Current loss 0.15463484823703766
#
# Epoch number 71
#  Current loss 0.17946940660476685
#
# Epoch number 71
#  Current loss 0.0802227258682251
#
# Epoch number 71
#  Current loss 0.28277090191841125
#
# Epoch number 71
#  Current loss 0.521140456199646
#
# Epoch number 72
#  Current loss 0.5014086961746216
#
# Epoch number 72
#  Current loss 0.1375025361776352
#
# Epoch number 72
#  Current loss 0.05550398677587509
#
# Epoch number 72
#  Current loss 0.21139800548553467
#
# Epoch number 72
#  Current loss 0.08285795152187347
#
# Epoch number 73
#  Current loss 0.1849406659603119
#
# Epoch number 73
#  Current loss 0.2408895492553711
#
# Epoch number 73
#  Current loss 0.42569252848625183
#
# Epoch number 73
#  Current loss 0.7782859802246094
#
# Epoch number 73
#  Current loss 0.12461908161640167
#
# Epoch number 74
#  Current loss 0.041582562029361725
#
# Epoch number 74
#  Current loss 0.0761328935623169
#
# Epoch number 74
#  Current loss 0.04297616705298424
#
# Epoch number 74
#  Current loss 0.1780872941017151
#
# Epoch number 74
#  Current loss 0.2800186276435852
#
# Epoch number 75
#  Current loss 0.20937198400497437
#
# Epoch number 75
#  Current loss 0.2701478898525238
#
# Epoch number 75
#  Current loss 0.08788445591926575
#
# Epoch number 75
#  Current loss 0.003992061130702496
#
# Epoch number 75
#  Current loss 0.14110837876796722
#
# Epoch number 76
#  Current loss 0.03152031451463699
#
# Epoch number 76
#  Current loss 0.17032469809055328
#
# Epoch number 76
#  Current loss 0.007665752898901701
#
# Epoch number 76
#  Current loss 0.04194001108407974
#
# Epoch number 76
#  Current loss 0.03393300622701645
#
# Epoch number 77
#  Current loss 0.1294548660516739
#
# Epoch number 77
#  Current loss 0.09775431454181671
#
# Epoch number 77
#  Current loss 0.06327588111162186
#
# Epoch number 77
#  Current loss 0.02676117792725563
#
# Epoch number 77
#  Current loss 0.12553100287914276
#
# Epoch number 78
#  Current loss 0.07024186849594116
#
# Epoch number 78
#  Current loss 0.3050529658794403
#
# Epoch number 78
#  Current loss 0.12234937399625778
#
# Epoch number 78
#  Current loss 0.040699321776628494
#
# Epoch number 78
#  Current loss 0.07510460913181305
#
# Epoch number 79
#  Current loss 0.07950731366872787
#
# Epoch number 79
#  Current loss 0.06606315821409225
#
# Epoch number 79
#  Current loss 0.05328616127371788
#
# Epoch number 79
#  Current loss 0.16331671178340912
#
# Epoch number 79
#  Current loss 0.08030238747596741
#
# Epoch number 80
#  Current loss 0.08073453605175018
#
# Epoch number 80
#  Current loss 0.025450406596064568
#
# Epoch number 80
#  Current loss 0.25920140743255615
#
# Epoch number 80
#  Current loss 0.002626487286761403
#
# Epoch number 80
#  Current loss 0.06951187551021576
#
# Epoch number 81
#  Current loss 0.030118850991129875
#
# Epoch number 81
#  Current loss 0.10708896815776825
#
# Epoch number 81
#  Current loss 0.04610995948314667
#
# Epoch number 81
#  Current loss 0.09643684327602386
#
# Epoch number 81
#  Current loss 0.015690458938479424
#
# Epoch number 82
#  Current loss 0.029316110536456108
#
# Epoch number 82
#  Current loss 0.057662978768348694
#
# Epoch number 82
#  Current loss 0.04480352997779846
#
# Epoch number 82
#  Current loss 0.13650323450565338
#
# Epoch number 82
#  Current loss 0.024306222796440125
#
# Epoch number 83
#  Current loss 0.2603469491004944
#
# Epoch number 83
#  Current loss 0.1014467403292656
#
# Epoch number 83
#  Current loss 0.029110215604305267
#
# Epoch number 83
#  Current loss 0.07870389521121979
#
# Epoch number 83
#  Current loss 0.03065728023648262
#
# Epoch number 84
#  Current loss 0.02227427065372467
#
# Epoch number 84
#  Current loss 0.04073905199766159
#
# Epoch number 84
#  Current loss 0.062182165682315826
#
# Epoch number 84
#  Current loss 0.015968237072229385
#
# Epoch number 84
#  Current loss 0.13742052018642426
#
# Epoch number 85
#  Current loss 0.010624160058796406
#
# Epoch number 85
#  Current loss 0.059006042778491974
#
# Epoch number 85
#  Current loss 0.017431268468499184
#
# Epoch number 85
#  Current loss 0.0595194548368454
#
# Epoch number 85
#  Current loss 0.1690189242362976
#
# Epoch number 86
#  Current loss 0.008091193623840809
#
# Epoch number 86
#  Current loss 0.06646363437175751
#
# Epoch number 86
#  Current loss 0.07687000930309296
#
# Epoch number 86
#  Current loss 0.014674262143671513
#
# Epoch number 86
#  Current loss 0.07287902384996414
#
# Epoch number 87
#  Current loss 0.05033661425113678
#
# Epoch number 87
#  Current loss 0.005159731954336166
#
# Epoch number 87
#  Current loss 0.01593749225139618
#
# Epoch number 87
#  Current loss 0.02247212827205658
#
# Epoch number 87
#  Current loss 0.17753790318965912
#
# Epoch number 88
#  Current loss 0.1646006852388382
#
# Epoch number 88
#  Current loss 0.03179790452122688
#
# Epoch number 88
#  Current loss 0.036484457552433014
#
# Epoch number 88
#  Current loss 0.061016567051410675
#
# Epoch number 88
#  Current loss 0.014622567221522331
#
# Epoch number 89
#  Current loss 0.08237603306770325
#
# Epoch number 89
#  Current loss 0.06450910121202469
#
# Epoch number 89
#  Current loss 0.09823895990848541
#
# Epoch number 89
#  Current loss 0.08523477613925934
#
# Epoch number 89
#  Current loss 0.009953669272363186
#
# Epoch number 90
#  Current loss 0.01628090627491474
#
# Epoch number 90
#  Current loss 0.04692544415593147
#
# Epoch number 90
#  Current loss 0.034964993596076965
#
# Epoch number 90
#  Current loss 0.0679890587925911
#
# Epoch number 90
#  Current loss 0.027891874313354492
#
# Epoch number 91
#  Current loss 0.028684435412287712
#
# Epoch number 91
#  Current loss 0.02331344597041607
#
# Epoch number 91
#  Current loss 0.05107669159770012
#
# Epoch number 91
#  Current loss 0.05399789661169052
#
# Epoch number 91
#  Current loss 0.08327271044254303
#
# Epoch number 92
#  Current loss 0.022549115121364594
#
# Epoch number 92
#  Current loss 0.041095294058322906
#
# Epoch number 92
#  Current loss 0.13431958854198456
#
# Epoch number 92
#  Current loss 0.09537734091281891
#
# Epoch number 92
#  Current loss 0.041999053210020065
#
# Epoch number 93
#  Current loss 0.018448907881975174
#
# Epoch number 93
#  Current loss 0.09354397654533386
#
# Epoch number 93
#  Current loss 0.016728974878787994
#
# Epoch number 93
#  Current loss 0.12217427790164948
#
# Epoch number 93
#  Current loss 0.01599268428981304
#
# Epoch number 94
#  Current loss 0.0241849347949028
#
# Epoch number 94
#  Current loss 0.08796662837266922
#
# Epoch number 94
#  Current loss 0.014128448441624641
#
# Epoch number 94
#  Current loss 0.02663111872971058
#
# Epoch number 94
#  Current loss 0.04364268481731415
#
# Epoch number 95
#  Current loss 0.04538391903042793
#
# Epoch number 95
#  Current loss 0.07114382088184357
#
# Epoch number 95
#  Current loss 0.009656981565058231
#
# Epoch number 95
#  Current loss 0.03937959298491478
#
# Epoch number 95
#  Current loss 0.0288398340344429
#
# Epoch number 96
#  Current loss 0.012745371088385582
#
# Epoch number 96
#  Current loss 0.016867872327566147
#
# Epoch number 96
#  Current loss 0.0023595301900058985
#
# Epoch number 96
#  Current loss 0.023997575044631958
#
# Epoch number 96
#  Current loss 0.03793571889400482
#
# Epoch number 97
#  Current loss 0.06925356388092041
#
# Epoch number 97
#  Current loss 0.020530367270112038
#
# Epoch number 97
#  Current loss 0.025526046752929688
#
# Epoch number 97
#  Current loss 0.0035261402372270823
#
# Epoch number 97
#  Current loss 0.13425198197364807
#
# Epoch number 98
#  Current loss 0.020698053762316704
#
# Epoch number 98
#  Current loss 0.07933258265256882
#
# Epoch number 98
#  Current loss 0.010705783031880856
#
# Epoch number 98
#  Current loss 0.011952441185712814
#
# Epoch number 98
#  Current loss 0.021743735298514366
#
# Epoch number 99
#  Current loss 0.003256401978433132
#
# Epoch number 99
#  Current loss 0.02241922728717327
#
# Epoch number 99
#  Current loss 0.00882399920374155
#
# Epoch number 99
#  Current loss 0.054974064230918884
#
# Epoch number 99
#  Current loss 0.021725796163082123

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
