# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "./data/faces/training/"
    testing_dir = "./data/faces/testing/"
    train_batch_size = 2
    train_number_epochs = 100

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [1.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# 6587023735046
#
# Epoch number 78
#  Current loss 0.010282061994075775
#
# Epoch number 78
#  Current loss 0.0
#
# Epoch number 78
#  Current loss 0.011059168726205826
#
# Epoch number 78
#  Current loss 0.022988686338067055
#
# Epoch number 78
#  Current loss 0.01106372382491827
#
# Epoch number 78
#  Current loss 0.019292231649160385
#
# Epoch number 78
#  Current loss 0.0008640785235911608
#
# Epoch number 78
#  Current loss 0.0017817041371017694
#
# Epoch number 78
#  Current loss 0.005905613303184509
#
# Epoch number 79
#  Current loss 0.017576951533555984
#
# Epoch number 79
#  Current loss 0.026416927576065063
#
# Epoch number 79
#  Current loss 0.0
#
# Epoch number 79
#  Current loss 0.02676626481115818
#
# Epoch number 79
#  Current loss 0.022955646738409996
#
# Epoch number 79
#  Current loss 0.03665424510836601
#
# Epoch number 79
#  Current loss 0.024521518498659134
#
# Epoch number 79
#  Current loss 0.03954583778977394
#
# Epoch number 79
#  Current loss 0.003552143694832921
#
# Epoch number 79
#  Current loss 0.02819850668311119
#
# Epoch number 79
#  Current loss 0.0026586628518998623
#
# Epoch number 79
#  Current loss 0.010592518374323845
#
# Epoch number 79
#  Current loss 0.0009495810372754931
#
# Epoch number 79
#  Current loss 0.015320779755711555
#
# Epoch number 79
#  Current loss 0.0
#
# Epoch number 79
#  Current loss 0.0010330937802791595
#
# Epoch number 79
#  Current loss 0.035630788654088974
#
# Epoch number 79
#  Current loss 0.004212449304759502
#
# Epoch number 79
#  Current loss 0.048497967422008514
#
# Epoch number 80
#  Current loss 0.0
#
# Epoch number 80
#  Current loss 0.005045078229159117
#
# Epoch number 80
#  Current loss 0.032176148146390915
#
# Epoch number 80
#  Current loss 0.007317753043025732
#
# Epoch number 80
#  Current loss 0.003541890298947692
#
# Epoch number 80
#  Current loss 0.00594640988856554
#
# Epoch number 80
#  Current loss 0.0018133105477318168
#
# Epoch number 80
#  Current loss 0.004885652102530003
#
# Epoch number 80
#  Current loss 0.007094330154359341
#
# Epoch number 80
#  Current loss 0.007113602943718433
#
# Epoch number 80
#  Current loss 0.005943827331066132
#
# Epoch number 80
#  Current loss 0.0
#
# Epoch number 80
#  Current loss 0.6128445267677307
#
# Epoch number 80
#  Current loss 0.03187760338187218
#
# Epoch number 80
#  Current loss 0.0217902809381485
#
# Epoch number 80
#  Current loss 0.0645633339881897
#
# Epoch number 80
#  Current loss 0.01738727279007435
#
# Epoch number 80
#  Current loss 0.0
#
# Epoch number 80
#  Current loss 0.015660900622606277
#
# Epoch number 81
#  Current loss 0.04834706708788872
#
# Epoch number 81
#  Current loss 0.0
#
# Epoch number 81
#  Current loss 0.0040779076516628265
#
# Epoch number 81
#  Current loss 0.026913326233625412
#
# Epoch number 81
#  Current loss 0.0
#
# Epoch number 81
#  Current loss 0.004780375864356756
#
# Epoch number 81
#  Current loss 0.0
#
# Epoch number 81
#  Current loss 0.0009912790264934301
#
# Epoch number 81
#  Current loss 0.007334382738918066
#
# Epoch number 81
#  Current loss 0.010325441136956215
#
# Epoch number 81
#  Current loss 0.013815025798976421
#
# Epoch number 81
#  Current loss 0.0
#
# Epoch number 81
#  Current loss 0.00781827699393034
#
# Epoch number 81
#  Current loss 0.008294904604554176
#
# Epoch number 81
#  Current loss 0.0
#
# Epoch number 81
#  Current loss 0.0015342739643529058
#
# Epoch number 81
#  Current loss 0.02036549337208271
#
# Epoch number 81
#  Current loss 0.003369587706401944
#
# Epoch number 81
#  Current loss 0.01996462233364582
#
# Epoch number 82
#  Current loss 0.015178042463958263
#
# Epoch number 82
#  Current loss 0.008140647783875465
#
# Epoch number 82
#  Current loss 0.030409881845116615
#
# Epoch number 82
#  Current loss 0.014247836545109749
#
# Epoch number 82
#  Current loss 0.007853761315345764
#
# Epoch number 82
#  Current loss 0.05318531394004822
#
# Epoch number 82
#  Current loss 0.21338695287704468
#
# Epoch number 82
#  Current loss 0.005442016292363405
#
# Epoch number 82
#  Current loss 0.002894487464800477
#
# Epoch number 82
#  Current loss 0.008499115705490112
#
# Epoch number 82
#  Current loss 0.0
#
# Epoch number 82
#  Current loss 0.0
#
# Epoch number 82
#  Current loss 0.03835591673851013
#
# Epoch number 82
#  Current loss 0.01926565170288086
#
# Epoch number 82
#  Current loss 0.0
#
# Epoch number 82
#  Current loss 0.11013384163379669
#
# Epoch number 82
#  Current loss 0.0
#
# Epoch number 82
#  Current loss 0.025571607053279877
#
# Epoch number 82
#  Current loss 0.0
#
# Epoch number 83
#  Current loss 0.0
#
# Epoch number 83
#  Current loss 0.009678177535533905
#
# Epoch number 83
#  Current loss 0.014248490333557129
#
# Epoch number 83
#  Current loss 0.009029832668602467
#
# Epoch number 83
#  Current loss 0.013222950510680676
#
# Epoch number 83
#  Current loss 0.007425555028021336
#
# Epoch number 83
#  Current loss 0.02157648839056492
#
# Epoch number 83
#  Current loss 0.0
#
# Epoch number 83
#  Current loss 0.005018449854105711
#
# Epoch number 83
#  Current loss 0.0
#
# Epoch number 83
#  Current loss 0.046590447425842285
#
# Epoch number 83
#  Current loss 0.3952453136444092
#
# Epoch number 83
#  Current loss 0.026205668225884438
#
# Epoch number 83
#  Current loss 0.014195729047060013
#
# Epoch number 83
#  Current loss 0.0
#
# Epoch number 83
#  Current loss 0.017721842974424362
#
# Epoch number 83
#  Current loss 0.0
#
# Epoch number 83
#  Current loss 0.015069672837853432
#
# Epoch number 83
#  Current loss 0.0
#
# Epoch number 84
#  Current loss 0.015129322186112404
#
# Epoch number 84
#  Current loss 0.019806498661637306
#
# Epoch number 84
#  Current loss 0.04499224200844765
#
# Epoch number 84
#  Current loss 0.019290560856461525
#
# Epoch number 84
#  Current loss 0.08022818714380264
#
# Epoch number 84
#  Current loss 0.05360199511051178
#
# Epoch number 84
#  Current loss 0.020070046186447144
#
# Epoch number 84
#  Current loss 0.18923430144786835
#
# Epoch number 84
#  Current loss 0.0017978462856262922
#
# Epoch number 84
#  Current loss 0.01567559875547886
#
# Epoch number 84
#  Current loss 0.00871372316032648
#
# Epoch number 84
#  Current loss 0.0
#
# Epoch number 84
#  Current loss 0.011359487660229206
#
# Epoch number 84
#  Current loss 0.3674161732196808
#
# Epoch number 84
#  Current loss 0.0066084726713597775
#
# Epoch number 84
#  Current loss 0.014179295860230923
#
# Epoch number 84
#  Current loss 0.032917946577072144
#
# Epoch number 84
#  Current loss 0.013958744704723358
#
# Epoch number 84
#  Current loss 0.08762817084789276
#
# Epoch number 85
#  Current loss 0.10278724879026413
#
# Epoch number 85
#  Current loss 0.03265068307518959
#
# Epoch number 85
#  Current loss 0.014365113340318203
#
# Epoch number 85
#  Current loss 0.04727423936128616
#
# Epoch number 85
#  Current loss 0.011186343617737293
#
# Epoch number 85
#  Current loss 0.036068517714738846
#
# Epoch number 85
#  Current loss 0.0
#
# Epoch number 85
#  Current loss 0.0015869967173784971
#
# Epoch number 85
#  Current loss 0.050803229212760925
#
# Epoch number 85
#  Current loss 0.07907718420028687
#
# Epoch number 85
#  Current loss 0.0049184830859303474
#
# Epoch number 85
#  Current loss 0.017300888895988464
#
# Epoch number 85
#  Current loss 0.03211827948689461
#
# Epoch number 85
#  Current loss 0.007128882221877575
#
# Epoch number 85
#  Current loss 0.013880312442779541
#
# Epoch number 85
#  Current loss 0.0
#
# Epoch number 85
#  Current loss 0.004641049541532993
#
# Epoch number 85
#  Current loss 0.011819613166153431
#
# Epoch number 85
#  Current loss 0.008878268301486969
#
# Epoch number 86
#  Current loss 0.012090921401977539
#
# Epoch number 86
#  Current loss 0.04256215691566467
#
# Epoch number 86
#  Current loss 0.0045863245613873005
#
# Epoch number 86
#  Current loss 0.041969045996665955
#
# Epoch number 86
#  Current loss 0.027885764837265015
#
# Epoch number 86
#  Current loss 0.02127595990896225
#
# Epoch number 86
#  Current loss 0.00016117504856083542
#
# Epoch number 86
#  Current loss 0.050950270146131516
#
# Epoch number 86
#  Current loss 0.011414766311645508
#
# Epoch number 86
#  Current loss 0.05790449678897858
#
# Epoch number 86
#  Current loss 0.012458546087145805
#
# Epoch number 86
#  Current loss 0.058742932975292206
#
# Epoch number 86
#  Current loss 0.022271938621997833
#
# Epoch number 86
#  Current loss 0.004591627977788448
#
# Epoch number 86
#  Current loss 0.01144960056990385
#
# Epoch number 86
#  Current loss 0.006768851540982723
#
# Epoch number 86
#  Current loss 0.0
#
# Epoch number 86
#  Current loss 0.020854884758591652
#
# Epoch number 86
#  Current loss 0.0
#
# Epoch number 87
#  Current loss 0.006930135190486908
#
# Epoch number 87
#  Current loss 0.07469088584184647
#
# Epoch number 87
#  Current loss 0.015944829210639
#
# Epoch number 87
#  Current loss 0.17063181102275848
#
# Epoch number 87
#  Current loss 0.0
#
# Epoch number 87
#  Current loss 0.2623123228549957
#
# Epoch number 87
#  Current loss 0.0
#
# Epoch number 87
#  Current loss 0.0
#
# Epoch number 87
#  Current loss 0.0
#
# Epoch number 87
#  Current loss 0.0020748116075992584
#
# Epoch number 87
#  Current loss 0.05992214009165764
#
# Epoch number 87
#  Current loss 0.18098124861717224
#
# Epoch number 87
#  Current loss 0.0
#
# Epoch number 87
#  Current loss 0.018279677256941795
#
# Epoch number 87
#  Current loss 0.0029374852310866117
#
# Epoch number 87
#  Current loss 0.09143411368131638
#
# Epoch number 87
#  Current loss 0.006576760206371546
#
# Epoch number 87
#  Current loss 0.003510841866955161
#
# Epoch number 87
#  Current loss 0.0
#
# Epoch number 88
#  Current loss 0.01711597666144371
#
# Epoch number 88
#  Current loss 0.013806197792291641
#
# Epoch number 88
#  Current loss 0.04560156911611557
#
# Epoch number 88
#  Current loss 0.021407518535852432
#
# Epoch number 88
#  Current loss 0.0
#
# Epoch number 88
#  Current loss 0.0
#
# Epoch number 88
#  Current loss 0.006550455931574106
#
# Epoch number 88
#  Current loss 0.0016238016542047262
#
# Epoch number 88
#  Current loss 0.045098334550857544
#
# Epoch number 88
#  Current loss 0.0024669438134878874
#
# Epoch number 88
#  Current loss 0.0
#
# Epoch number 88
#  Current loss 0.03367912396788597
#
# Epoch number 88
#  Current loss 0.03737363591790199
#
# Epoch number 88
#  Current loss 0.12940183281898499
#
# Epoch number 88
#  Current loss 0.0
#
# Epoch number 88
#  Current loss 0.023927509784698486
#
# Epoch number 88
#  Current loss 0.019391871988773346
#
# Epoch number 88
#  Current loss 0.019596580415964127
#
# Epoch number 88
#  Current loss 0.10571358352899551
#
# Epoch number 89
#  Current loss 0.03349023684859276
#
# Epoch number 89
#  Current loss 0.010837823152542114
#
# Epoch number 89
#  Current loss 0.0
#
# Epoch number 89
#  Current loss 0.011648575775325298
#
# Epoch number 89
#  Current loss 0.0
#
# Epoch number 89
#  Current loss 0.011519942432641983
#
# Epoch number 89
#  Current loss 0.01610243134200573
#
# Epoch number 89
#  Current loss 0.0
#
# Epoch number 89
#  Current loss 0.16637930274009705
#
# Epoch number 89
#  Current loss 0.0048123933374881744
#
# Epoch number 89
#  Current loss 0.034011196345090866
#
# Epoch number 89
#  Current loss 0.0016630413010716438
#
# Epoch number 89
#  Current loss 0.0
#
# Epoch number 89
#  Current loss 0.01888091117143631
#
# Epoch number 89
#  Current loss 0.026558170095086098
#
# Epoch number 89
#  Current loss 0.013280796818435192
#
# Epoch number 89
#  Current loss 0.0804440900683403
#
# Epoch number 89
#  Current loss 0.055202629417181015
#
# Epoch number 89
#  Current loss 0.0
#
# Epoch number 90
#  Current loss 0.06696127355098724
#
# Epoch number 90
#  Current loss 0.024170327931642532
#
# Epoch number 90
#  Current loss 0.0
#
# Epoch number 90
#  Current loss 0.00374986813403666
#
# Epoch number 90
#  Current loss 0.015785017982125282
#
# Epoch number 90
#  Current loss 0.0071435412392020226
#
# Epoch number 90
#  Current loss 0.002720022341236472
#
# Epoch number 90
#  Current loss 0.03182773292064667
#
# Epoch number 90
#  Current loss 0.0036786135751754045
#
# Epoch number 90
#  Current loss 0.022392751649022102
#
# Epoch number 90
#  Current loss 0.012200398370623589
#
# Epoch number 90
#  Current loss 0.0
#
# Epoch number 90
#  Current loss 0.009900885634124279
#
# Epoch number 90
#  Current loss 0.01783936657011509
#
# Epoch number 90
#  Current loss 0.03685722127556801
#
# Epoch number 90
#  Current loss 0.0
#
# Epoch number 90
#  Current loss 0.0015440593706443906
#
# Epoch number 90
#  Current loss 0.013142895884811878
#
# Epoch number 90
#  Current loss 0.07280517369508743
#
# Epoch number 91
#  Current loss 0.039722226560115814
#
# Epoch number 91
#  Current loss 0.06507977098226547
#
# Epoch number 91
#  Current loss 0.03586433827877045
#
# Epoch number 91
#  Current loss 0.0249945055693388
#
# Epoch number 91
#  Current loss 0.0011308633256703615
#
# Epoch number 91
#  Current loss 0.0
#
# Epoch number 91
#  Current loss 0.03142387792468071
#
# Epoch number 91
#  Current loss 0.022120783105492592
#
# Epoch number 91
#  Current loss 0.0
#
# Epoch number 91
#  Current loss 0.003541690995916724
#
# Epoch number 91
#  Current loss 0.0
#
# Epoch number 91
#  Current loss 0.003651204751804471
#
# Epoch number 91
#  Current loss 0.0
#
# Epoch number 91
#  Current loss 0.022251805290579796
#
# Epoch number 91
#  Current loss 0.029053514823317528
#
# Epoch number 91
#  Current loss 0.008630795404314995
#
# Epoch number 91
#  Current loss 0.05387694388628006
#
# Epoch number 91
#  Current loss 0.01286366954445839
#
# Epoch number 91
#  Current loss 0.04301303252577782
#
# Epoch number 92
#  Current loss 0.015421515330672264
#
# Epoch number 92
#  Current loss 0.0
#
# Epoch number 92
#  Current loss 0.013383276760578156
#
# Epoch number 92
#  Current loss 0.011576204560697079
#
# Epoch number 92
#  Current loss 0.016649490222334862
#
# Epoch number 92
#  Current loss 0.015485337935388088
#
# Epoch number 92
#  Current loss 0.0
#
# Epoch number 92
#  Current loss 0.010656742379069328
#
# Epoch number 92
#  Current loss 0.020726487040519714
#
# Epoch number 92
#  Current loss 0.14582830667495728
#
# Epoch number 92
#  Current loss 0.004915826953947544
#
# Epoch number 92
#  Current loss 0.004443232901394367
#
# Epoch number 92
#  Current loss 0.01373263355344534
#
# Epoch number 92
#  Current loss 0.009058499708771706
#
# Epoch number 92
#  Current loss 0.003911405336111784
#
# Epoch number 92
#  Current loss 0.004028179217129946
#
# Epoch number 92
#  Current loss 0.032681070268154144
#
# Epoch number 92
#  Current loss 0.02751043438911438
#
# Epoch number 92
#  Current loss 0.0006400458514690399
#
# Epoch number 93
#  Current loss 0.022835349664092064
#
# Epoch number 93
#  Current loss 0.004542006645351648
#
# Epoch number 93
#  Current loss 0.01592271775007248
#
# Epoch number 93
#  Current loss 0.0
#
# Epoch number 93
#  Current loss 0.0
#
# Epoch number 93
#  Current loss 0.005776307545602322
#
# Epoch number 93
#  Current loss 0.0
#
# Epoch number 93
#  Current loss 0.0066387588158249855
#
# Epoch number 93
#  Current loss 0.031249307096004486
#
# Epoch number 93
#  Current loss 0.020380742847919464
#
# Epoch number 93
#  Current loss 0.0015980753814801574
#
# Epoch number 93
#  Current loss 0.0019100815989077091
#
# Epoch number 93
#  Current loss 0.01107101235538721
#
# Epoch number 93
#  Current loss 0.01973944902420044
#
# Epoch number 93
#  Current loss 0.005733647849410772
#
# Epoch number 93
#  Current loss 0.004308586474508047
#
# Epoch number 93
#  Current loss 0.01995193585753441
#
# Epoch number 93
#  Current loss 0.00028013280825689435
#
# Epoch number 93
#  Current loss 0.029145315289497375
#
# Epoch number 94
#  Current loss 0.0034159100614488125
#
# Epoch number 94
#  Current loss 0.0
#
# Epoch number 94
#  Current loss 0.00042168566142208874
#
# Epoch number 94
#  Current loss 0.04520515352487564
#
# Epoch number 94
#  Current loss 0.04383331537246704
#
# Epoch number 94
#  Current loss 0.0
#
# Epoch number 94
#  Current loss 0.009838560596108437
#
# Epoch number 94
#  Current loss 0.1650596559047699
#
# Epoch number 94
#  Current loss 0.013036615215241909
#
# Epoch number 94
#  Current loss 0.02720513567328453
#
# Epoch number 94
#  Current loss 0.018680015578866005
#
# Epoch number 94
#  Current loss 0.07157730311155319
#
# Epoch number 94
#  Current loss 0.027057897299528122
#
# Epoch number 94
#  Current loss 0.012245280668139458
#
# Epoch number 94
#  Current loss 0.13088083267211914
#
# Epoch number 94
#  Current loss 0.014135734178125858
#
# Epoch number 94
#  Current loss 0.02377568930387497
#
# Epoch number 94
#  Current loss 0.08254915475845337
#
# Epoch number 94
#  Current loss 0.7173902988433838
#
# Epoch number 95
#  Current loss 0.0636926144361496
#
# Epoch number 95
#  Current loss 0.003987402655184269
#
# Epoch number 95
#  Current loss 0.006774218287318945
#
# Epoch number 95
#  Current loss 0.0
#
# Epoch number 95
#  Current loss 0.00738516915589571
#
# Epoch number 95
#  Current loss 0.011094174347817898
#
# Epoch number 95
#  Current loss 0.03315291553735733
#
# Epoch number 95
#  Current loss 0.00132239970844239
#
# Epoch number 95
#  Current loss 0.006014795508235693
#
# Epoch number 95
#  Current loss 0.014416685327887535
#
# Epoch number 95
#  Current loss 0.011895783245563507
#
# Epoch number 95
#  Current loss 0.026308203116059303
#
# Epoch number 95
#  Current loss 0.04560644179582596
#
# Epoch number 95
#  Current loss 0.08948211371898651
#
# Epoch number 95
#  Current loss 0.015444689430296421
#
# Epoch number 95
#  Current loss 0.10347878932952881
#
# Epoch number 95
#  Current loss 0.008259788155555725
#
# Epoch number 95
#  Current loss 0.02901017852127552
#
# Epoch number 95
#  Current loss 0.0
#
# Epoch number 96
#  Current loss 0.0
#
# Epoch number 96
#  Current loss 0.018646763637661934
#
# Epoch number 96
#  Current loss 0.03786325082182884
#
# Epoch number 96
#  Current loss 0.05053109675645828
#
# Epoch number 96
#  Current loss 0.01954571343958378
#
# Epoch number 96
#  Current loss 0.0017551013734191656
#
# Epoch number 96
#  Current loss 0.007886797189712524
#
# Epoch number 96
#  Current loss 0.005810799077153206
#
# Epoch number 96
#  Current loss 0.009747002273797989
#
# Epoch number 96
#  Current loss 0.010148651897907257
#
# Epoch number 96
#  Current loss 0.014253632165491581
#
# Epoch number 96
#  Current loss 0.014175131916999817
#
# Epoch number 96
#  Current loss 0.0
#
# Epoch number 96
#  Current loss 0.03091987408697605
#
# Epoch number 96
#  Current loss 0.0
#
# Epoch number 96
#  Current loss 0.006738841067999601
#
# Epoch number 96
#  Current loss 0.002680291887372732
#
# Epoch number 96
#  Current loss 0.001752296811901033
#
# Epoch number 96
#  Current loss 0.10178105533123016
#
# Epoch number 97
#  Current loss 0.20030319690704346
#
# Epoch number 97
#  Current loss 0.022735895588994026
#
# Epoch number 97
#  Current loss 0.004469423554837704
#
# Epoch number 97
#  Current loss 0.02085043303668499
#
# Epoch number 97
#  Current loss 0.003681060392409563
#
# Epoch number 97
#  Current loss 0.14927059412002563
#
# Epoch number 97
#  Current loss 0.025412127375602722
#
# Epoch number 97
#  Current loss 0.015024068765342236
#
# Epoch number 97
#  Current loss 0.0
#
# Epoch number 97
#  Current loss 0.029615582898259163
#
# Epoch number 97
#  Current loss 0.006345727015286684
#
# Epoch number 97
#  Current loss 0.05654718354344368
#
# Epoch number 97
#  Current loss 0.0
#
# Epoch number 97
#  Current loss 0.0013332711532711983
#
# Epoch number 97
#  Current loss 0.0056320615112781525
#
# Epoch number 97
#  Current loss 0.0056133572943508625
#
# Epoch number 97
#  Current loss 0.013457735069096088
#
# Epoch number 97
#  Current loss 0.012856772169470787
#
# Epoch number 97
#  Current loss 0.0030898693948984146
#
# Epoch number 98
#  Current loss 0.053254712373018265
#
# Epoch number 98
#  Current loss 0.017350170761346817
#
# Epoch number 98
#  Current loss 0.0028024225030094385
#
# Epoch number 98
#  Current loss 0.01209783274680376
#
# Epoch number 98
#  Current loss 0.003538105869665742
#
# Epoch number 98
#  Current loss 0.013911501504480839
#
# Epoch number 98
#  Current loss 0.0034484821371734142
#
# Epoch number 98
#  Current loss 0.0013471245765686035
#
# Epoch number 98
#  Current loss 0.007132187485694885
#
# Epoch number 98
#  Current loss 0.0018154707504436374
#
# Epoch number 98
#  Current loss 0.0208126287907362
#
# Epoch number 98
#  Current loss 0.0
#
# Epoch number 98
#  Current loss 0.014722328633069992
#
# Epoch number 98
#  Current loss 0.0
#
# Epoch number 98
#  Current loss 0.030585767701268196
#
# Epoch number 98
#  Current loss 0.011828886345028877
#
# Epoch number 98
#  Current loss 0.23231546580791473
#
# Epoch number 98
#  Current loss 0.018159016966819763
#
# Epoch number 98
#  Current loss 0.048086658120155334
#
# Epoch number 99
#  Current loss 0.1173543855547905
#
# Epoch number 99
#  Current loss 0.007027783896774054
#
# Epoch number 99
#  Current loss 0.051176682114601135
#
# Epoch number 99
#  Current loss 0.0
#
# Epoch number 99
#  Current loss 0.005048907827585936
#
# Epoch number 99
#  Current loss 0.0018581789918243885
#
# Epoch number 99
#  Current loss 9.091852007259149e-06
#
# Epoch number 99
#  Current loss 0.022786511108279228
#
# Epoch number 99
#  Current loss 0.005013425834476948
#
# Epoch number 99
#  Current loss 0.004636474419385195
#
# Epoch number 99
#  Current loss 0.10804763436317444
#
# Epoch number 99
#  Current loss 0.0027639339677989483
#
# Epoch number 99
#  Current loss 0.0
#
# Epoch number 99
#  Current loss 0.023891828954219818
#
# Epoch number 99
#  Current loss 0.022909151390194893
#
# Epoch number 99
#  Current loss 0.0
#
# Epoch number 99
#  Current loss 4.999999980020986e-12
#
# Epoch number 99
#  Current loss 0.019885212182998657
#
# Epoch number 99
#  Current loss 0.001953029539436102

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
